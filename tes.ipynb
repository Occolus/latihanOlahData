# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#inisialisasi csv customer
customers_df = pd.read_csv(r"D:\ML Dicoding\latihanCleaningData\customers.csv")
#print(customers_df.head())

#inisialisasi csv order
order_df = pd.read_csv(r"D:\ML Dicoding\latihanCleaningData\orders.csv")
#print(order_df.head)

#inisialisasi csv product
product_df = pd.read_csv(r"D:\ML Dicoding\latihanCleaningData\products.csv")
#print(product_df.head)

# %% [markdown]
# # penilaian tiap csv

# %% [markdown]
#  penilaian sales

# %%
#inisialisasi csv sales
sales_df = pd.read_csv(r"D:\ML Dicoding\latihanCleaningData\sales.csv")
sales_df.isna().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %% [markdown]
# dapat dilihat total price yang bernilai null ada 19

# %%
sales_df.isna().sum()[sales_df.isna().sum() > 0]
sales_df[sales_df['total_price'].isna()]
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# 278        278        63         360              94         2          NaN
# 421        421        95        1091             115         1          NaN
# 489        489       108        1193             105         3          NaN
# 539        539       117         405             119         2          NaN
# 636        636       134         653              93         3          NaN
# 687        687       145        1138             102         1          NaN
# 854        854       177          64             104         1          NaN
# 1079      1079       222         908              94         3          NaN
# 1193      1193       248        1121             102         2          NaN
# ...

# %% [markdown]
# dari hasil diatas, ditemukan order id yang value nya null. lanjut untuk pengecekan duplikasi.

# %%
print("jumlah duplikasi data sales : ", sales_df.duplicated().sum())
# Out:
# jumlah duplikasi data sales :  0

# %% [markdown]
# duplikasi aman.

# %%
customers_df.isna().sum()[customers_df.isna().sum() > 0]
customers_df[customers_df['gender'].isna()]
# Out:
#      customer_id customer_name gender  age                     home_address  \
# 38            39      fulan 39    NaN   80  7440 Cameron Estate DrSuite 628
# 167          168     fulan 168    NaN   27         2781 Berge MallSuite 452
# 322          322     fulan 322    NaN   30        593 Becker CircleApt. 333
# 393          393     fulan 393    NaN   34          5158 Levi HillSuite 531
# 442          442     fulan 442    NaN   26           5157 Feil RoadApt. 633
# 722          720     fulan 720    NaN   40         31 Jordan ParadeApt. 400
# 745          743     fulan 743    NaN   57   09 Christopher StreetSuite 967
# 773          771     fulan 771    NaN   74     7367 Wright JunctionApt. 773
# 798          795     fulan 795    NaN   49          487 Summer MewsApt. 874
# 801          798     fulan 798    NaN   56           27 Aiden KnollApt. 875
# 825          822     fulan 822    NaN   59        41 Jenkins KnollSuite 438
# ...

# %%
customers_df.describe(include="all")
# Out:
#         customer_id customer_name             gender          age  \
# count   1007.000000          1007                989  1007.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 808  Prefer not to say          NaN
# freq            NaN             3                731          NaN
# mean     501.726912           NaN                NaN    50.929494
# std      288.673238           NaN                NaN    30.516299
# min        1.000000           NaN                NaN    20.000000
# 25%      252.500000           NaN                NaN    34.000000
# 50%      502.000000           NaN                NaN    50.000000
# 75%      751.500000           NaN                NaN    65.000000
# max     1000.000000           NaN                NaN   700.000000
#
#                      home_address     zip_code         city            state  \
# count                        1007  1007.000000         1007             1007
# ...
